# %%
import __init__
#
import pandas as pd

# %%
from community_analysis import regressionModel_dpath
df = pd.read_csv('%s/%s' % (regressionModel_dpath, 'fb/regressionModel-fb-2009-G(3).csv'))

# %%
gn_drivers = set(df['did'])

# %%
len(gn_drivers)
# Out:
# 90

# %%
did1 = 37562
#
# df
did_df = df[(df['did'] == did1) & (df['roamingTime'] <= 3600) & (df['roamingTime'] > 0) & (df['%d' % did1] == 1) ].copy(deep=True)
# did_df
other_dids = ['%d' % did0 for did0 in gn_drivers.difference(set([did1]))]

res = pd.ols(y = did_df['did'], x = did_df[other_dids])
res
# pd.ols()

# result = sm.ols(formula="%d ~ %s" % (did1, ' + '.join(['%d' % did0 for did0 in other_dids])), data=df).fit()
# Out:
# /usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2869: FutureWarning: The pandas.stats.ols module is deprecated and will be removed in a future version. We refer to external packages like statsmodels, see some examples here: http://statsmodels.sourceforge.net/stable/regression.html
#   exec(code_obj, self.user_global_ns, self.user_ns)
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <34826> + <35863> + <4634> + <5158> + <8113> + <44072> + <34350>
#              + <8240> + <11827> + <18485> + <3126> + <43575> + <19040> + <23620>
#              + <20549> + <35399> + <19528> + <3147> + <22100> + <3674> + <34398>
#              + <34912> + <22122> + <34413> + <15478> + <35092> + <20602> + <20603>
#              + <6561> + <11389> + <38021> + <11911> + <37513> + <23185> + <13973>
#              + <41117> + <35495> + <1198> + <6831> + <35005> + <3783> + <8904>
# ...

# %%
print dir(res)
# Out:
# ['RESULT_FIELDS', '__bytes__', '__class__', '__delattr__', '__dict__', '__doc__', '__format__', '__getattribute__', '__hash__', '__init__', '__module__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__unicode__', '__weakref__', '_beta_raw', '_cache', '_coef_table', '_df_model_raw', '_df_raw', '_df_resid_raw', '_f_stat_raw', '_index', '_intercept', '_nobs', '_nw_lags', '_nw_overlap', '_p_value_raw', '_panel_model', '_prepare_data', '_r2_adj_raw', '_r2_raw', '_resid_raw', '_results', '_rmse_raw', '_std_err_raw', '_t_stat_raw', '_time_has_obs', '_time_obs_count', '_total_times', '_use_centered_tss', '_var_beta_raw', '_weights', '_weights_orig', '_x', '_x_filtered', '_x_orig', '_x_trans', '_y', '_y_fitted_raw', '_y_orig', '_y_predict_raw', '_y_trans', 'beta', 'df', 'df_model', 'df_resid', 'f_stat', 'f_test', 'nobs', 'nw_lags', 'p_value', 'predict', 'r2', 'r2_adj', 'resid', 'rmse', 'sm_ols', 'std_err', 'summary', 'summa
# ...

# %%
candi_did1 = []
for did1, pv in res.p_value.iteritems():
    if did1 == 'intercept':
        continue
    if pv < 0.05:
        candi_did1.append(did1)
candi_did1        
#     print did1, pv
# Out:
# ['5158',
#  '18485',
#  '20549',
#  '3674',
#  '34912',
#  '22122',
#  '20603',
#  '11389',
#  '38021',
#  '37513',
#  '13973',
#  '35495',
#  '1198',
#  '6831',
#  '35005',
#  '4218',
#  '9439',
#  '35577',
#  '36614',
#  '7947',
#  '27355',
#  '35158',
#  '5025',
#  '34728',
#  '8608']

# %%
['27355', '31658']
# res1 = pd.ols(y = did_df['did'], x = did_df[candi_did1])
res1 = pd.ols(y = did_df['did'], x = did_df['20549'])

res1
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <x> + <intercept>
#
# Number of Observations:         885
# Number of Degrees of Freedom:   2
#
# R-squared:           -inf
# Adj R-squared:       -inf
#
# Rmse:              0.0000
#
# F-stat (1, 883):        nan, p-value:        nan
#
# Degrees of Freedom: model 1, resid 883
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#              x    -0.0000     0.0000      -2.64     0.0084    -0.0000    -0.0000
#      intercept 37562.0000     0.0000 8519840704294017.00     0.0000 37562.0000 37562.0000
# ---------------------------------End of Summary---------------------------------

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(12,6))
plt.scatter(did_df['20549'], did_df['did'], color='black')
plt.show()

# %%
temp_df = did_df[['roamingTime']+ candi_did1].copy(deep=True)
temp_df.sort_values(by=['roamingTime'], ascending=[False])[50:]
# print len(did_df), len(temp_df[(temp_df['27355'] == 1) | (temp_df['31658'] == 1)])
# temp_df[(temp_df['27355'] == 1) | (temp_df['31658'] == 1)].sort_values(by=['roamingTime'], ascending=[False])
# Out:
#          roamingTime  27355  31658
# 85239           1389      0      0
# 252188          1383      0      0
# 43124           1380      0      0
# 1006023         1344      0      0
# 323975          1340      0      0
# 397920          1329      0      0
# 1204743         1329      0      0
# 310090          1324      0      1
# 202104          1303      0      1
# 562964          1301      0      0
# 529839          1294      0      0
# 321136          1288      0      0
# 559372          1264      0      0
# 922147          1261      0      0
# 698026          1251      0      0
# 738766          1247      0      0
# 511947          1241      0      0
# 702995          1235      0      0
# 172763          1215      0      0
# 646977          1213      0      0
# 90961           1213      0      0
# 459536          1207      0      0
# 42256           1205      0      0
# 666806          1204      0      0
# 39704           1203      0      0
# 305233          1202      0      0
# ...

# %%
for did1 in gn_drivers:
    did_df = df[(df['did'] == did1) & (df['roamingTime'] <= 3600) & (df['roamingTime'] > 0) ].copy(deep=True)
    other_dids = gn_drivers.difference(set([did1]))
    print len(did_df), ' + '.join(['%d' % did0 for did0 in other_dids])
    result = sm.ols(formula="A ~ B + C", data=df).fit()
    assert False
# Out:
#  13449 35863 + 4634 + 5158 + 8113 + 44072 + 34350 + 8240 + 11827 + 18485 + 3126 + 43575 + 19040 + 23620 + 20549 + 35399 + 19528 + 3147 + 22100 + 3674 + 34398 + 34912 + 22122 + 34413 + 15478 + 35092 + 20602 + 20603 + 6561 + 11389 + 38021 + 11911 + 37513 + 23185 + 13973 + 41117 + 35495 + 1198 + 6831 + 37562 + 35005 + 3783 + 8904 + 10969 + 46299 + 4218 + 9439 + 36576 + 10990 + 35577 + 34050 + 36614 + 7947 + 6932 + 34593 + 27355 + 9510 + 8327 + 37165 + 35646 + 35158 + 9063 + 362 + 36670 + 22390 + 34679 + 21882 + 38279 + 9619 + 3483 + 34720 + 5025 + 7074 + 13733 + 34728 + 31658 + 8263 + 20913 + 25529 + 8608 + 22978 + 30625 + 10185 + 19408 + 14291 + 10708 + 8664 + 24545 + 15333 + 15339
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-13-f62cbe9a0a44> in <module>()
#       3     other_dids = gn_drivers.difference(set([did1]))
# ...

# %%
import __init__
#
from IPython.display import HTML, display
import pandas as pd
import numpy as np
#
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Airport

# %%
from information_boards import statisticsAllDrivers_ap_dpath
from information_boards import statisticsAllDriversDay_ap_prefix
#
dfDayAP = pd.read_csv('%s/%sall.csv' % (statisticsAllDrivers_ap_dpath, statisticsAllDriversDay_ap_prefix))
for cn in dfDayAP.columns:
    if cn in ['year', 'month', 'day', 'driverID']:
        continue
    dfDayAP = dfDayAP[~(np.abs(dfDayAP[cn] - dfDayAP[cn].mean()) > (3 * dfDayAP[cn].std()))]

# %%
dfDayAP['QTime/locTrip'].hist()

# %%
from information_boards import statisticsAllDrivers_ap_dpath
from information_boards import statisticsAllDriversMonth_ap_prefix
Y2009 = pd.read_csv('%s/%s2009.csv' % (statisticsAllDrivers_ap_dpath, statisticsAllDriversMonth_ap_prefix))
Y2010 = pd.read_csv('%s/%s2010.csv' % (statisticsAllDrivers_ap_dpath, statisticsAllDriversMonth_ap_prefix))

# %%
Y2009.columns
# Out:
# Index([u'year', u'month', u'driverID', u'wleTripNumber', u'wleOperatingHour',
#        u'wleFare', u'wleProductivity', u'locTripNumber', u'locInNumber',
#        u'locOutNumber', u'locQTime', u'locEP', u'locDuration', u'locFare',
#        u'QTime/locTrip', u'EP/locTrip', u'locProductivity', u'locInRatio',
#        u'timePassed', u'timePassed^2'],
#       dtype='object')

# %%
Y2009['locInRatio'].hist()

# %%
Y2009['wleTripNumber'].hist()

# %%
print Y2009['locTripNumber'].mean(), Y2009['locTripNumber'].max()
Y2009['locTripNumber'].hist()
# Out:
# 11.4355078055 237

# %%
print Y2009['wleOperatingHour'].mean(), Y2009['wleOperatingHour'].max()
Y2009['wleOperatingHour'].hist()
# Out:
# 54.6370710728 512.85

# %% [markdown]
# # Zoo

# %%
from information_boards import statisticsAllDrivers_ns_dpath
from information_boards import statisticsAllDriversDay_ns1519_prefix
#
dfDayZ = pd.read_csv('%s/%sall.csv' % (statisticsAllDrivers_ns_dpath, statisticsAllDriversDay_ns1519_prefix))
for cn in dfDayAP.columns:
    if cn in ['year', 'month', 'day', 'driverID']:
        continue
    dfDayZ = dfDayZ[~(np.abs(dfDayZ[cn] - dfDayZ[cn].mean()) > (3 * dfDayZ[cn].std()))]

# %%
dfDayZ.columns
# Out:
# Index([u'year', u'month', u'day', u'driverID', u'wleTripNumber',
#        u'wleOperatingHour', u'wleFare', u'wleProductivity', u'locTripNumber',
#        u'locInNumber', u'locOutNumber', u'locQTime', u'locEP', u'locDuration',
#        u'locFare', u'QTime/locTrip', u'EP/locTrip', u'locProductivity'],
#       dtype='object')

# %%
dfDayZ['QTime/locTrip'].hist()

# %%
dfDayZ['QTime/locTrip'].hist()

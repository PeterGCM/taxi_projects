# %%
import __init__
#
from IPython.display import HTML, display
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def display_dist(df, cn, m, sd):
    print 'mean %.3f' % m
    print 'sigma %.3f; 2sigma %.3f; 3sigma %.3f;' % (sd, 2 * sd, 3 * sd)
    df[cn].hist()

# %%
from information_boards import statisticsAllDrivers_ap_dpath
from information_boards import statisticsAllDriversTrip_ap_prefix
Y2009 = pd.read_csv('%s/%s2009.csv' % (statisticsAllDrivers_ap_dpath, statisticsAllDriversTrip_ap_prefix))
Y2010 = pd.read_csv('%s/%s2010.csv' % (statisticsAllDrivers_ap_dpath, statisticsAllDriversTrip_ap_prefix))

# %%
print len(Y2009)
outlier_index = set()
for cn in Y2009.columns:
    if cn in ['year', 'month', 'day','hour', 'driverID']:
        continue
    if cn == 'locQTime':
        outlier_set = set(np.where(Y2009[cn] > 120)[0].tolist())
        outlier_index = outlier_index.union(set(outlier_set))
    outlier_set = np.where((np.abs(Y2009[cn] - Y2009[cn].mean()) > (3 * Y2009[cn].std())))[0]
    outlier_index = outlier_index.union(set(outlier_set))
print len(outlier_index)
Y2009 = Y2009.drop(Y2009.index[list(outlier_index)])
# Out:
# 2120567
# 60089

# %%
print len(Y2010)
outlier_index = set()
for cn in Y2010.columns:
    if cn in ['year', 'month', 'day','hour', 'driverID']:
        continue
    if cn == 'locQTime':
        outlier_set = set(np.where(Y2010[cn] > 120)[0].tolist())
        outlier_index = outlier_index.union(set(outlier_set))
    outlier_set = np.where((np.abs(Y2010[cn] - Y2010[cn].mean()) > (3 * Y2010[cn].std())))[0]
    outlier_index = outlier_index.union(set(outlier_set))
print len(outlier_index)
Y2010 = Y2010.drop(Y2010.index[list(outlier_index)])
# Out:
# 2601981
# 58054

# %%
cn = 'locQTime'
print '%s: after Filtering' % cn
m, sd = Y2009[cn].mean(), Y2009[cn].std()
display_dist(Y2009, cn, m, sd)
# Out:
# locQTime: after Filtering
# mean 36.168
# sigma 22.122; 2sigma 44.244; 3sigma 66.366;

# %%
cn = 'locEP'
print '%s: after Filtering' % cn
m, sd = Y2009[cn].mean(), Y2009[cn].std()
display_dist(Y2009, cn, m, sd)
# Out:
# locEP: after Filtering
# mean -1.662
# sigma 8.889; 2sigma 17.778; 3sigma 26.667;

# %%
cn = 'locProductivity'
print '%s: after Filtering' % cn
m, sd = Y2009[cn].mean(), Y2009[cn].std()
display_dist(Y2009, cn, m, sd)
# Out:
# locProductivity: after Filtering
# mean 24.111
# sigma 10.516; 2sigma 21.032; 3sigma 31.548;

# %%
Y2009.columns
# Out:
# Index([u'year', u'month', u'day', u'hour', u'driverID', u'locQTime', u'locEP',
#        u'locDuration', u'locFare', u'locProductivity', u'locIn', u'weekEnd',
#        u'timePassed', u'timePassed^2'],
#       dtype='object')

# %%
Y2009.to_csv('%s/Filtered-%s2009.csv' % (statisticsAllDrivers_ap_dpath, statisticsAllDriversTrip_ap_prefix) ,index=False)
Y2010.to_csv('%s/Filtered-%s2010.csv' % (statisticsAllDrivers_ap_dpath, statisticsAllDriversTrip_ap_prefix) ,index=False)
